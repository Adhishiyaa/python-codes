# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/reverse_numbers_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=input("please enter your number")
num2=("")
for i in num:
  num2=i+num2
  print("\n the original number you have entered is:",num)
  print("the reversed number of the number you've entered is:", num2)
# Out:
# please enter your number273193012
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 2
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 72
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 372
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 1372
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 91372
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 391372
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 0391372
#
#  the original number you have entered is: 273193012
# the reversed number of the number you've entered is: 10391372
#
# ...
