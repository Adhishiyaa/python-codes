# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/age_project_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("enter your age"))
if age >= 10 and age <= 20:
  print("your age is valid and you're qualified")
else:
  print("your age is invalid and you're not qualified yet ")
# Out:
# enter your age12
# your age is valid and you're qualified
