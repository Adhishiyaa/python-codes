# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/power_number%2Cpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1=int(input("enter the first number whose power you want to find:"))
num2=int(input("enter the the power number"))
result = 1
for _ in range(num2):
    result = result * num1
print(f"{num1} raised to the power of {num2} is: {result}")
# Out:
# enter the first number whose power you want to find:27
# enter the the power number30
# 27 raised to the power of 30 is: 8727963568087712425891397479476727340041449
