# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/circumference_py_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def calculate_circumference(radius):
    """Function to calculate the circumference of a circle."""
    return 2 * math.pi * radius
user_radius = float(input("Enter the radius of the circle: "))
result = calculate_circumference(user_radius)
print(f"The circumference of the circle is: {result:.2f}")
# Out:
# Enter the radius of the circle: 9
# The circumference of the circle is: 56.55
