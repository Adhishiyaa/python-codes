# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rows=int(input("enter the number of rows needed to be printed"))
for i in range(1, rows + 1):
  for j in range(1, i-1):
    print("*",end="")
print()
# Out:
# enter the number of rows needed to be printed7
# ***************
