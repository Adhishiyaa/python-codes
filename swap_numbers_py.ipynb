# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/swap_numbers_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
c=int(input("enter the third number"))
a,b,c=b,c,a
print("after swapping the numbers")
print("a=", a)
print("b=", b)
print("c=", c)
# Out:
# enter the first number901
# enter the second number30
# enter the third number12
# after swapping the numbers
# a= 30
# b= 12
# c= 901
