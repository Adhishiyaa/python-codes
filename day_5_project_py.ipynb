# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/day_5_project_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
actual_temp=27
temperature_for_wearing_light_and_soft_dress=30-3
if(actual_temp==temperature_for_wearing_light_and_soft_dress):
  print("you can wear a light and soft dress for:",actual_temp)
else:
  print("you can't wear a light and soft for this:",actual_temp)
print("here is your answer for your question 'whether to wear a light and soft dress for the actual temperature now'")
# Out:
# you can wear a light and soft dress for: 27
# here is your answer for your question 'whether to wear a light and soft dress for the actual temperature now'
