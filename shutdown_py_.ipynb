# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/shutdown_py_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_age(age):
    if age < 18:
        print("Access denied.")
        return
    print("Access granted. Welcome!")
check_age(15)
