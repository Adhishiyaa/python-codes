# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/character_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
char = input("Enter a character: ")
if ('a' <= char <= 'z') or ('A' <= char <= 'Z'):
    print(f"'{char}' is an Alphabet.")
else:
    print(f"'{char}' is not an Alphabet.")
# Out:
# Enter a character: a
# 'a' is an Alphabet.
