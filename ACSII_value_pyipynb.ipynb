# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhishiyaa/python-codes/blob/main/ACSII_value_pyipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
char = 'A'
ascii_value = ord(char)
print(f"The ASCII value of '{char}' is {ascii_value}")
# Out:
# The ASCII value of 'A' is 65
